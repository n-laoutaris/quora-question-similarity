# %% [markdown]
# # Text Data Cleaning and EDA Overview
# This notebook documents the process of cleaning and exploring the Quora question pairs dataset. The goal is to identify and address common text issues to prepare the data for downstream NLP tasks. Each step below highlights a specific problem, the rationale for addressing it and the solution applied.

# %%
import pandas as pd
import re
import contractions
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import nltk
from tqdm.notebook import tqdm
import unicodedata

# %%
# Set display options for pandas
pd.set_option('display.max_colwidth',1000)
pd.set_option('display.max_rows', 100)

# Download necessary NLTK resources
nltk.download('stopwords')

# Set up tqdm for pandas
tqdm.pandas()

# %%
df = pd.read_csv('quora.csv')
df['question1'] = df['question1'].astype(str)
df['question2'] = df['question2'].astype(str)

# %% [markdown]
# Now we will scan the dataframe to see what needs cleaning and what doesn't.

# %% [markdown]
# ## Step 1: Detecting and Handling HTML Tags
# Text data scraped from the web often contains HTML tags, which can interfere with NLP models. Here, we identify questions containing HTML and replace tags with descriptive tokens to preserve information while removing markup.

# %%
# Problem: HTML tags
# detect using regex: starts with < followed by a letter and ends with >
html_pattern = re.compile(r'</?[a-zA-Z][^>]*>')

# Check for HTML in both columns
q1_html = df[df['question1'].astype(str).apply(lambda x: bool(html_pattern.search(x)))]
q2_html = df[df['question2'].astype(str).apply(lambda x: bool(html_pattern.search(x)))]

# Display summary
print(f"Total questions with HTML tags in question1: {len(q1_html)}")
print(f"Total questions with HTML tags in question2: {len(q2_html)}")

# Concatenate for side-by-side view (not preserving pairs)
html_examples = pd.concat([q1_html['question1'].reset_index(drop=True), q2_html['question2'].reset_index(drop=True)], axis=1)

# Show top 25 rows
html_examples[['question1', 'question2']].head(25)
# Out:
# Total questions with HTML tags in question1: 32
# Total questions with HTML tags in question2: 24
#                                                                                                                                    question1  \
# 0                                                                                                            “><img src=x onerror=prompt(1)>
# 1                     Is this the correct way to implement a stack using an arrayList<Integer> and a queue as an arrayList<Integer> in Java?
# 2                                                                  What is the function of <head> <title>Page Title</title> </head> in HTML?
# 3                                                                             How do you make one <div> layer show over another in HTML/CSS?
# 4                                                                    Avg antivirus 1800</v\>251<’-‘>4919 Avg tech support phone number 24x7?
# 5                                      How can one define a constant <img> src URL in HTML, so that it can be reused in multiple attributes?
# 6                                                                                                                 What is #include<stdio.h>?
# 7                                                             How do I open a windows file/folders in local drive using html "<a href>" tag?
# 8                                                                    Avg antivirus 1800</v\>251<’-‘>4919 Avg tech support phone number 24x7?
# 9                                                                                                                 What is #include<stdio.h>?
# 10                                                                                                                Why use #include<conio.h>?
# 11  Is it legal to use another website image using HTML code <img src ="another_website_image.jpg"> without asking permission to the author?
# 12                                                                                                                       What is <iostream>?
# 13                                                                                                                What is #include<conio.h>?
# 14                                                                             Why is the proxy class vector<bool>::reference needed in C++?
# 15                                                                   Avg antivirus 1800</v\>251<’-‘>4919 Avg tech support phone number 24x7?
# 16                                                                                    How do I display a <div> table when a link is clicked?
# 17                                                                                           How can I add <graphic.h> directory in Dev C++?
# 18                               What is the difference between READ TABLE <ITAB> WITH KEY and READ TABLE <ITAB> WITH TABLE KEY in SAP ABAP?
# 19                                                                                                                What is #include<conio.h>?
# 20                                                                   Avg antivirus 1800</v\>251<’-‘>4919 Avg tech support phone number 24x7?
# 21                                                                   Avg antivirus 1800</v\>251<’-‘>4919 Avg tech support phone number 24x7?
# 22  Is it legal to use another website image using HTML code <img src ="another_website_image.jpg"> without asking permission to the author?
# 23                                                                                               Do <abbr> HTML tags have any effect on SEO?
# 24                                                                   What is the difference between #include<stdio.h> and #include"stdio.h"?
#
#                                                                                                                                                                                                question2
# 0                                                                                                                                                                      "><img src=x onerror=prompt(0) >?
# 1                                                                                                                                                                        “><img src=x onerror=prompt(1)>
# 2                                                                                                                      What are the pros and <bold>cons</bold> of demonetizing Rs.500 and Rs.1000 notes?
# 3                                                                                                                                                                             What is #include<conio.h>?
# 4                                                                                                                              What do T1,T2,FLAIR, <D>, and FA tell you about someone's brain from MRI?
# 5                                                                                                                                                          <h1 style="color: blue;">HTML injection</h1>?
# 6                                                                                                                                                               What is the h for in #include <stdio.h>?
# 7                                                                                                                                                                             What is #include<stdio.h>?
# 8                                                                                                                                                                            What is #include<stdlib.h>?
# 9                                                                                                                                How do I display a <div> table when a link is clicked? (variable-based)
# 10                                                                                                          What is the difference between the HTML tags <b> and <strong>? Are there HTML 5 corrections?
# 11                                                                                                                     What are the pros and <bold>cons</bold> of demonetizing Rs.500 and Rs.1000 notes?
# 12                                                                                                                     What are the pros and <bold>cons</bold> of demonetizing Rs.500 and Rs.1000 notes?
# 13                                                                                                                                                Why CodeBlocks is not recognizing #include <iostream>?
# 14                                                                                                                                                            Is "do do … <noun>" grammatically correct?
# 15  How does this code work: #include<stdio.h> main() {int r,c, sum; for (r=1;r<=3;r=c) {for (c=1;c<=2;c=r) {sum=r+c; printf ("r=%d c=%d sum=%d\n", r,c, sum);} printf ("%d\n", c);}}? Why does it work?
# 16                                                                                                                               Avg antivirus 1800</v\>251<’-‘>4919 Avg tech support phone number 24x7?
# 17                                                                                                                                                                         ';"><u>test123 is a derp lol?
# 18                                                                                                                     What are the pros and <bold>cons</bold> of demonetizing Rs.500 and Rs.1000 notes?
# 19                                                                                               <marquee loop=1 width=0 onfinish=alert(1) > <marquee loop=1 width=0 onfinish=alert (document.domain) >?
# 20                                                                                                                                                                            What is #include<conio.h>?
# 21                                                                                                                               Avg antivirus 1800</v\>251<’-‘>4919 Avg tech support phone number 24x7?
# 22                                                                                                                               Avg antivirus 1800</v\>251<’-‘>4919 Avg tech support phone number 24x7?
# 23                                                                                                                                   Which is correct to use for icons in HTML code, <I> or <span> tags?
# 24                                                                                                                                                                                                   NaN

# %%
# Solution: encode tags : replace them with tokens.
def tag_to_token(text):
    return re.sub(r'</?([a-zA-Z]+)[^>]*>', r' \1tag ', text)

df['q1_html'] = df['question1'].astype(str).apply(tag_to_token)
df['q2_html'] = df['question2'].astype(str).apply(tag_to_token)

# Check results
q1_html = df[df['q1_html'].astype(str).apply(lambda x: bool(html_pattern.search(x)))]
q2_html = df[df['q2_html'].astype(str).apply(lambda x: bool(html_pattern.search(x)))]
print(f"Total questions with HTML tags in question1: {len(q1_html)}")
print(f"Total questions with HTML tags in question2: {len(q2_html)}")
html_examples = pd.concat([q1_html['q1_html'].reset_index(drop=True), q2_html['q2_html'].reset_index(drop=True)], axis=1)
html_examples[['q1_html', 'q2_html']].head(25)
# Out:
# Total questions with HTML tags in question1: 0
# Total questions with HTML tags in question2: 0
# Empty DataFrame
# Columns: [q1_html, q2_html]
# Index: []

# %% [markdown]
# ## Step 2: Expanding Contractions and Removing Possessives
# Contractions and possessives can introduce inconsistencies in text analysis. This step expands contractions (e.g., "can't" to "cannot") and removes possessive forms.

# %%
# Problem: contractions, possessives, apostrophes in general

# Filter rows that contain common contractions
contractions_pattern = r"\b(?:I'm|you're|he's|she's|it's|we're|they're|I've|you've|they've|I'd|you'd|we'd|I'll|you'll|won't|can't|n't|'re|'ve|'ll|'d|'s)\b"
contractions_q1 = df[df['question1'].str.contains(contractions_pattern, case=False, na=False)]
contractions_q2 = df[df['question2'].str.contains(contractions_pattern, case=False, na=False)]

# Display summary
print(f"Total questions with contractions in question1: {len(contractions_q1)}")
print(f"Total questions with contractions in question2: {len(contractions_q2)}")

# Concatenate for side-by-side view (not preserving pairs)
contraction_examples = pd.concat([contractions_q1['question1'].reset_index(drop=True), contractions_q2['question2'].reset_index(drop=True)], axis=1)

# Show top 25 rows
contraction_examples[['question1', 'question2']].head(25)
# Out:
# Total questions with contractions in question1: 25517
# Total questions with contractions in question2: 25326
#                                                                                                                                                                                                                                                question1  \
# 0                                                                                                                                                                                                                  What's causing someone to be jealous?
# 1                                                                                                                                                                                                          What's one thing you would like to do better?
# 2                                                                                                                                    I'm a 19-year-old. How can I improve my skills or what should I do to become an entrepreneur in the next few years?
# 3                                                                                                                                                                                       What is the best/most memorable thing you've ever eaten and why?
# 4                                                                                                            I was suddenly logged off Gmail. I can't remember my Gmail password and just realized the recovery email is no longer alive. What can I do?
# 5                                                                                                                                                                                             How do I log out of my Gmail account on my friend's phone?
# 6                                                                                                    When will the BJP government strip all the Muslims and the Christians of the Indian citizenship and put them on boats like the Rohingya's of Burma?
# 7                                                                                                                                                                                                           What's the difference between love and pity?
# 8                                                                                                                                                                                        What is the most creative college admissions essay you've read?
# 9                                                                                                                                                                                                        What's the best way to start learning robotics?
# 10                                                                                                                                                                                      What are the best quotes/lessons of the Assassin's Creed series?
# 11                                                                                                                                                              How many derivatives of an object's position with respect to time have to be continuous?
# 12                                                                                                                                                                       Trump supporters, how do you feel about the way he's walking back his promises?
# 13                                                                               There are 8 balls. 7 of them weigh the same. 1 of them has a different weight, (you don't know if it's heavier or lighter). How do you find the odd ball with 2 weighs?
# 14                                                                                                                                                                                                        What are your New Year's resolutions for 2017?
# 15                                                                                                                                                    What are the most interesting products and innovations that McDonald's is coming out with in 2016?
# 16                                                                                                                                                                     Should I repeat 2nd year in college, or find a new college? It's a 5 year course.
# 17  What's the best on-line calender/scheduling/booking system? Something that allows me to show my availability & customers can 'request' to meet me. When I 'accept' their request, the appointment pops into our calendars & reminders are automated.
# 18                                                                                                                                                                                                             What are 5 facts about the earth's crust?
# 19                                                                                                                                                                                                What's the best near-death experience you've ever had?
# 20                                                                                                                                                                                       Why does massaging one's temples soothe a migraine or headache?
# 21                                                                                                                                                                                                   What are the best self-help books you've ever read?
# 22                                                                                                  I argued with my gf that she made friends with the person that hit on her. She said I'm a control freak and she wants her freedom. What should I do?
# 23                                                                                                                                                                                                         Does a fetus breathe when it's inside a womb?
# 24                                                                                                                                                                                          Why is Oberon mad at Titania in "A Midsummer Night's Dream"?
#
#                                                                                                                                                                                                  question2
# 0                                                                                                               I'm a triple Capricorn (Sun, Moon and ascendant in Capricorn) What does this say about me?
# 1                                                                                                                                                          What's one thing you do despite knowing better?
# 2                                                                                                                                               What is the most delicious dish you've ever eaten and why?
# 3                                                                                                                                                                              Why can't I do my homework?
# 4                                                                                                                                          Do you apply for programs like RSI when you're a rising senior?
# 5                                                                                                                    I can't remember my Gmail password or my recovery email. How can I recover my e-mail?
# 6                                                                                                                                                 What's the purpose of life? What is life actually about?
# 7                                                                                                                                                        What's the difference between honest and sincere?
# 8                                                                                                                                                                            What's life after retirement?
# 9                                                                                                                    Has any college admission officer cried in public while reading an applicant's essay?
# 10                                                                                                                                                  Which assassin has the best robes in Assassin's Creed?
# 11                                                                                                                                                                           What's the PUK for TF64SIMC4?
# 12                                                                                                                                                                       What's the best way to jump rope?
# 13                                                                                                                                                   What is your creative New Year's resolution for 2017?
# 14                                                                                                                                                           How successful was the Delhi's Odd-even plan?
# 15                                                                                                                                                                         What's are the meaning of life?
# 16                                                                                                                                              What is the most delicious dish you've ever eaten and why?
# 17                                                                                                                                                             How does the Earth's core affect its crust?
# 18                                                       Should a guy re-evaluate his current relationship and feelings if he's worried about temptation hanging out with a girl that he was friends with?
# 19                                                              I'm a masters student interested to work in Humanitarian sector. What are the skills required? I'm a medical doctor doing my masters in UK
# 20                                                                                                                                                        What's the difference between between and among?
# 21                                                                                                                               If Jon Snow is not Ned's bastard, why does Lady Catelyn hate him so much?
# 22                                                                               I am an 18 years old boy and I love a girl who's 14 years old. We both live Tamil Nadu. Is this a time to propose to her?
# 23                                                                                                                       I'm a girl and I'm in love my best friend (who is also a girl), what should I do?
# 24  I'm a girl in middle school. My best friends are all girls. I've found out that I'm bisexual. How do I tell my best friend who's a girl without her freaking out and it changing our whole friendship?

# %%
# Solution: Expand contractions

def expand_contractions(text):
    return contractions.fix(text)

#  on both columns
df['q1_expanded'] = df['question1'].apply(expand_contractions)
df['q2_expanded'] = df['question2'].apply(expand_contractions)

# Optionally remove possesives completely
def remove_possesives(text):
    return re.sub(r"(?i)\b's\b", "", text)

df['q1_expanded'] = df['q1_expanded'].apply(remove_possesives)
df['q2_expanded'] = df['q2_expanded'].apply(remove_possesives)

# Check results
contractions_q1 = df[df['q1_expanded'].str.contains(contractions_pattern, case=False, na=False)]
contractions_q2 = df[df['q2_expanded'].str.contains(contractions_pattern, case=False, na=False)]
print(f"Total questions with contractions in question1: {len(contractions_q1)}")
print(f"Total questions with contractions in question2: {len(contractions_q2)}")
contraction_examples = pd.concat([contractions_q1['q1_expanded'].reset_index(drop=True), contractions_q2['q2_expanded'].reset_index(drop=True)], axis=1)
contraction_examples[['q1_expanded', 'q2_expanded']].head(25)
# Out:
# Total questions with contractions in question1: 5
# Total questions with contractions in question2: 9
#                                                                                                                              q1_expanded  \
# 0                                                                                                  Can Adam'D Angelo be banned on Quora?
# 1                                                                    How can I catch a Farfetch'd in Pokémon Go while visiting in China?
# 2                                                                        How do I identify the original Skullcandy earphones, Ink'd 2.0?
# 3  I am looking to switch from android to IOS. Give me some reasons, suggestions and insight into why I should/n't? Always used android.
# 4                          What would have Theodore Hertzl'd proposed seven starred flag from his “the Jewish state” actually look like?
# 5                                                                                                                                    NaN
# 6                                                                                                                                    NaN
# 7                                                                                                                                    NaN
# 8                                                                                                                                    NaN
#
#                                                                                                                                                                                                                                                                                     q2_expanded
# 0                                                                                                                                                                                                                            I am 15 and 5'll.So starting bodybuilding at this age a good idea?
# 1                                                                                                                                                                                                                WI'll it be easy to get job in private sector after 2.5 years sitting jobless?
# 2                                                                                                                                                                                                                                                                   In Punk'd, who is the punk?
# 3                                                                                                                                                                                                                  İ've heard that smoking 3 cigarettes a day does not harm health. Is it true?
# 4   I am a 5 letter word.  I am normally below you  If you remove my 1st letter   you'll find me above you  If you remove my 1st & 2nd letters  you cannot see me  Answer is really very interesting  Let us see who solves this.... ⏰Time limit :- today YOU can also send to other grps if I?
# 5                                                                                                                                                   Why cannot rich black people create their're own NBA, NFL team what is stopping them, nothing stop them in the past with the negro leagues?
# 6                                                                                                            If you only have 1099 salespeople and no W2'd employees, can you decide to turn some into W2 employees and keep some as 1099s? Can the ones who stay as 1099s do anything legally?
# 7                                                                                                                           Would you second guess your interactions on Quora if the site was SEO optimized and caused your answers to appear prominently when someone Google'd your name? Why?
# 8                                                                                               I go kind of blank when someone asks me, "what is up" or "how've you been?" How can one respond to these genuinely if his life is going just normal and there is nothing special to tell about?

# %% [markdown]
# ## Step 3: Normalizing Unicode and Removing Non-ASCII Characters
# Text data may contain accented or non-standard Unicode characters, which can cause issues for tokenization and modeling. This step normalizes text to a standard Unicode form and removes diacritics and unusual symbols.

# %%
# Problem: Non-ASCII (e.g., accented or unusual symbols)

# Regex to detect characters outside the basic ASCII range
non_ascii_pattern = re.compile(r'[^\x00-\x7F]')

# Mask for each column
q1_unicode = df[df['question1'].astype(str).apply(lambda x: bool(non_ascii_pattern.search(x)))]
q2_unicode = df[df['question2'].astype(str).apply(lambda x: bool(non_ascii_pattern.search(x)))]

# Display summary
print(f"Total questions with Non-ASCII in question1: {len(q1_unicode)}")
print(f"Total questions with Non-ASCII in question2: {len(q2_unicode)}")

# Concatenate for side-by-side view (not preserving pairs)
unicode_examples = pd.concat([q1_unicode['question1'].reset_index(drop=True), q2_unicode['question2'].reset_index(drop=True)], axis=1)

# Show top 25 rows
unicode_examples[['question1', 'question2']].head(25)
# Out:
# Total questions with Non-ASCII in question1: 5053
# Total questions with Non-ASCII in question2: 4559
#                                                                                                                                                  question1  \
# 0                                                                                                                          When do you use シ instead of し?
# 1                                                            What would a Trump presidency mean for current international master’s students on an F1 visa?
# 2   I got job offer @ Chelmsford-Essex, London with £3764 PM pay-after tax deduction. Pls advice tentative monthly expenses for couple? & saving possible?
# 3                              When travelling to a new region is it better to immerse yourself in 1–2 cities or to see as many cities as you can cram in?
# 4                                                                                        Why can’t charged molecules pass through the lipid cell membrane?
# 5                                                                                                                        What’s the best time to have sex?
# 6                       What would be today’s technology had we never realized the value of binary numbers and harnessed it to produce digital technology?
# 7      Whenever its about “her” its a very special feeling. Tried hard to forget her but she's alwys spcl. Should I stop talking to her even as a friend ?
# 8                                                                  What individuals and events in history are a source of pride for São Tomé and Príncipe?
# 9                                                         My parents give me "advice" and they get really mad if I dont take it… What am I supposed to do?
# 10                                                                                                         How long will the Pokémon GO "fever" will last?
# 11                                                                                 G. W. Bush Presidency (2001–09): Why was Donald Rumsfeld fired in 2006?
# 12                                                                                                                     What is “India Post Payments Bank”?
# 13                                                                                                                    What is the best quote you’ve heard?
# 14                                             What’s the difference between data, information and knowledge in machine systems? Or is there a difference?
# 15                                                                                      Do you think Hillary Clinton’s pneumonia will affect the election?
# 16                                                                                   Can I take vitamin B Complex without doctor’s prescription on my own?
# 17                                                                                                            What are your 2017 New Year’s resolution(s)?
# 18                                   Which one is correct? “please let me know if you have any question” or ”please let me know if you have any questions”
# 19                                                                                                             Which is the best SEO ‪Company‬ in ‪Delhi‬?
# 20       Is it a good idea for a CEO to take personal criminal liability for a non-profit? Such as "I, X , hereby certify, under penalty of perjury, that…
# 21                                                  What strikes first time visitors as special or unusual when they arrive in Timbuctú, Tombouctou, Mali?
# 22                                                                                      What really happened at MG Road, Bangalore on New Year’s Eve 2017?
# 23                                                                                                                 How difficult is it to hack Pokémon GO?
# 24                                                                                               How can I get free PokeCoins and Pokeballs on Pokémon GO?
#
#                                                                                                                                                   question2
# 0                                                                                                          How many times a day do a clock’s hands overlap?
# 1                                                                                     How can I ask a question without getting marked as ‘need to improve’?
# 2                                                                                                                What is it like to live in Köln, Germany?
# 3                                                             What will be the impact of scrapping of ₹500 and ₹1000 rupee notes on the real estate market?
# 4                                                                                                       How can I best invest ₹5000 over the next 6 months?
# 5                                                                                    What jobs are available with a bachelor’s degree in Homeland Security?
# 6                                                                                                                           Emoticons: What does “:/” mean?
# 7                                                                                                                         When will the Pokémon series end?
# 8                                                                                     Can poetry be learned? Or is it a “you have it or not" sort of thing?
# 9                    Why does Quora mark my questions as needing improvement/clarification before I have time to give it details? Literally within seconds…
# 10                                                                                                                              What is the Gülen movement?
# 11                                                                                    What are your views on demonetization of ₹500 & ₹1000 notes in India?
# 12                                                                        My fiancée died recently and it pains my heart, how do I learn to cope with this?
# 13              On Snapchat, someone blocked me, but still shows up in my added me section, but Snapchat still won't allow me to add them. What’s going on?
# 14                                                                                                      How can I learn English well as a Chinese student？?
# 15                             Why is Persian word “ذليل” meaning ‘a Muslim’ translated incorrectly on Microsoft Translator? Is it intentional or careless?
# 16                                     I want to move to IT but I don’t know programming nor do I want to do programming. Are there any other career paths?
# 17                                 What are going to be the rammifications of the Indian government's decision affecting invalid ₹500/₹1000 currency notes?
# 18                                                  Why didn't Aman Goel choose to do a master’s from a top college of the USA and instead decided to work?
# 19                                                                                                       What is the best thing I can buy for 2€ on Amazon?
# 20                                                                                                        What is your favorite top 10 list of “Sun” songs?
# 21                                                                                                      How long you thing this Pokémon GO trend will last?
# 22                                        What was the investigation outcome of Iran’s seizure of U.S. Navy patrol boats near Farsi Island in January 2016?
# 23  Which tools or methods can be used to track as to how often your followers/fans click “like” and comment upon the status updates you/your company post?
# 24                                                                                 In Pokémon Emerald, is there a Pokémon that can learn both surf and fly?

# %%
# Solution: Normalize characters to follow Unicode

def normalize_unicode(text, remove_accents=True):
    # Normalize to NFKD (decomposed form)
    text = unicodedata.normalize('NFKD', text)

    if remove_accents:
        # Remove diacritics (accents) by dropping combining characters
        text = ''.join([char for char in text if not unicodedata.combining(char)])

    # Re-compose characters (helps keep things standard)
    text = unicodedata.normalize('NFC', text)

    # Replace curly quotes dashes etc.
    text = text.replace('“', '"').replace('”', '"')
    text = text.replace("‘", "'").replace("’", "'")
    text = text.replace("–", "-").replace("—", "-")
    text = re.sub(r'\s+', ' ', text)  # for excess whitespace

    return text.strip()

df['q1_unicode'] = df['question1'].apply(normalize_unicode)
df['q2_unicode'] = df['question2'].apply(normalize_unicode)

# Check results
q1_unicode = df[df['q1_unicode'].astype(str).apply(lambda x: bool(non_ascii_pattern.search(x)))]
q2_unicode = df[df['q2_unicode'].astype(str).apply(lambda x: bool(non_ascii_pattern.search(x)))]
print(f"Total questions with Non-ASCII in question1: {len(q1_unicode)}")
print(f"Total questions with Non-ASCII in question2: {len(q2_unicode)}")
unicode_examples = pd.concat([q1_unicode['q1_unicode'].reset_index(drop=True), q2_unicode['q2_unicode'].reset_index(drop=True)], axis=1)
unicode_examples[['q1_unicode', 'q2_unicode']].head(25)
# Out:
# Total questions with Non-ASCII in question1: 974
# Total questions with Non-ASCII in question2: 1030
#                                                                                                                                                 q1_unicode  \
# 0                                                                                                                          When do you use シ instead of し?
# 1   I got job offer @ Chelmsford-Essex, London with £3764 PM pay-after tax deduction. Pls advice tentative monthly expenses for couple? & saving possible?
# 2                                                                                                              Which is the best SEO ‪Company‬ in ‪Delhi‬?
# 3                                                                                                                  What is the difference between ج and ز?
# 4                                                                                      How can I prove that (A × B) − (C × D) = (A − C) × B ∪ A × (B − D)?
# 5                                                    How will demonetization of ‎₹1000 and ‎₹500 notes will help curb the rampant black currency in India?
# 6                                                              Which are the positive benefits of banning existing ₹500 and ₹1000 currency notes in India?
# 7         Now after banning of ₹500 & ₹1000 notes, what are the ways in which people can convert their black money into white and how can it be prevented?
# 8                                                                                        What would be the quadratic equation for the roots 2+√2 and 2-√2?
# 9                   How much effect can banning of ₹500 and ₹1000 notes have on people having black money (won't have they invested their money in areas)?
# 10                                                                                     How do you pronounce the name of the Danish singer "MØ" in English?
# 11                                                                The decision of Indian Government to demonetize ₹500 and ₹1000 notes? Is Right or wrong?
# 12                             How do you interpret Søren Kierkegaard's view that "Life can only be understood backwards; but it must be lived forwards."?
# 13                                                                                                                                      What does 슬마 mean?
# 14                                                                                                          How to say "如果不靠欺骗自己,还能靠什么支撑自己走下去" in English?
# 15                                                                The decision of Indian Government to demonetize ₹500 and ₹1000 notes? Is Right or wrong?
# 16                                                                                                        What is the best product I can buy under ₹50000?
# 17                                                                                                                              Can you boil water at 0°C?
# 18                                                                             What is the world's view on the design of India's new ₹500 and ₹2000 notes?
# 19                                                                                                              What is the best smartphone within ₹10000?
# 20                                                                                                             Which is the best SEO ‪Company‬ in ‪Delhi‬?
# 21                                                                                                             Which smartphone has best camera in ₹20000?
# 22                                                                                           What is the difference between 高铁 (gaotie) and 动车 (dong che)?
# 23                                                                                                                            What does the symbol ¥ mean?
# 24                                                    What will be the positive and negative effects of demonization of ₹500/1000 notes on Indian economy?
#
#                                                                                                                                                                              q2_unicode
# 0                                                                                         What will be the impact of scrapping of ₹500 and ₹1000 rupee notes on the real estate market?
# 1                                                                                                                                   How can I best invest ₹5000 over the next 6 months?
# 2                                                                                                                 What are your views on demonetization of ₹500 & ₹1000 notes in India?
# 3                                                          Why is Persian word "ذليل" meaning 'a Muslim' translated incorrectly on Microsoft Translator? Is it intentional or careless?
# 4                                                              What are going to be the rammifications of the Indian government's decision affecting invalid ₹500/₹1000 currency notes?
# 5                                                                                                                                    What is the best thing I can buy for 2€ on Amazon?
# 6                                                                                                                                  How can I get Clash Of Clans Gem or Gold for free? ‎
# 7                                                                                                                                                                   What does 분위기 mean?
# 8                                                                                                                                             What is the relationship between e and π?
# 9                                                                                                                   How will discontinuing ₹500 and ₹1000 notes affect India's economy?
# 10                                                                                                                       How can I prove (A × B) − (C × D) = (A − C) × B ∪ A × (B − D)?
# 11                                                                                           RBI is planning to destroy 1000₹&500₹ notes, can't they recycle them for 100₹ & 50₹ notes?
# 12                                                                                                       Will the economy of India collapse due to the banning of ₹500 and ₹1000 notes?
# 13                                                                                                                                                       How would you translate "一百回"?
# 14                                                                                                                                              Why wasn't Harry Potter an Obscurial? ﻿
# 15                                                                                                                                         What are the Danish words with a lot of "ø"?
# 16                                                                      At what distance from earth's surface does ɡ0 (standard gravity) end and zero gravity or weightlessness starts?
# 17                                                                                                           What is the solution of this:- [{√ (√5+2) +√ (√5-2)} /√ (√5+1)]-√ (3-2√2)?
# 18                                                                                                                                                           Is 恬莉 a good Chinese name?
# 19                                                                                                                                   How's American Muslim's situation in America now?
# 20                                                                                                            How long will it take to heat 750kg of water by 10°C with a 2060W heater?
# 21                                                                                                                                                        How can I say 没出息 in English?
# 22                                    Why is it sometimes necessary to require δ ≤ 1 in a delta-epsilon proof and why do we have to let δ = minimum {1, epsilon/k} for some constant k?
# 23  If Vietnam had not been colonized by France, would the Vietnamese language still be using Chinese characters (Chu Nom / 字喃), like Japanese, and, to a lesser extent, Korean, today?
# 24                                                                                        How many hands need to be holding a cup of 1ml water 0°C at one time in order for it to boil?

# %% [markdown]
# ## Step 4: Handling Currency Symbols
# Currency symbols may not be handled well by standard tokenizers. Here we replace common currency symbols with their corresponding acronyms (e.g., $ to USD).

# %%
# Problem: Currency symbols

# Define common currency symbols (you can expand this if needed)
currency_symbols = r'[$€£¥₹₩₽₺฿₫₪₴₦]'

# Check for presence of currency symbols
q1_currency = df[df['question1'].astype(str).str.contains(currency_symbols, regex=True)]
q2_currency = df[df['question2'].astype(str).str.contains(currency_symbols, regex=True)]

# Display summary
print(f"Total questions with currency symbols in question1: {len(q1_currency)}")
print(f"Total questions with currency symbols in question2: {len(q2_currency)}")

# Concatenate for side-by-side view (not preserving pairs)
currency_examples = pd.concat([q1_currency['question1'].reset_index(drop=True), q2_currency['question2'].reset_index(drop=True)], axis=1)

# Show top 25 rows
currency_examples[['question1', 'question2']].head(25)
# Out:
# Total questions with currency symbols in question1: 1425
# Total questions with currency symbols in question2: 1499
#                                                                                                                                                  question1  \
# 0   I got job offer @ Chelmsford-Essex, London with £3764 PM pay-after tax deduction. Pls advice tentative monthly expenses for couple? & saving possible?
# 1                                                                                                      What is the easiest way to become a billionaire($)?
# 2                     What is the best way to invest $500 legally so that I can get tangible profits over a relatively short period of time, say 6 months?
# 3                                                                                         How comfortably can I live in Washington DC on a $80,000 salary?
# 4                                                                              If you make $130,000/year in NYC, what is your take-home bi-weekly payment?
# 5                                                A cab's flat rate is $6 at $0.75 per mile. How many miles could you travel if you only have $20 to spend?
# 6                                                                                                   Can a family live on $120,000 yearly in New York City?
# 7                                                                                               Why, or why not, should the minimum wage be raised to $15?
# 8                                               I want a real and effective way to make $ 500 per month with the knowledge that I have no money to invest?
# 9                                                                 What is the best waterproof and shockproof 15.6" laptop bag for every day use under $50?
# 10                                                                          Why does $500 trillion rich Rothschilds are not on Forbes richest people list?
# 11                       If someone paid you $1 million to walk into a public area in Israel, do the Nazi salute and shout "Heil Hitler," would you do it?
# 12                                                                                                        What side business can make you $500-$1000/week?
# 13                                                   How will demonetization of ‎₹1000 and ‎₹500 notes will help curb the rampant black currency in India?
# 14                                                             Which are the positive benefits of banning existing ₹500 and ₹1000 currency notes in India?
# 15        Now after banning of ₹500 & ₹1000 notes, what are the ways in which people can convert their black money into white and how can it be prevented?
# 16                                                                                                              How much does U.S. $500,000 weigh in cash?
# 17                  How much effect can banning of ₹500 and ₹1000 notes have on people having black money (won't have they invested their money in areas)?
# 18                                                                          Why does $500 trillion rich Rothschilds are not on Forbes richest people list?
# 19                                                                The decision of Indian Government to demonetize ₹500 and ₹1000 notes? Is Right or wrong?
# 20                                                                                            Can I retire with this farm lifestyle and $100,000K savings?
# 21                                                                                                   Is $1750 monthly quite enough to live in Phoenix, AZ?
# 22                                       I am 30 years old and want to start my own business. What kind of business can I start with just $50,000 in hand?
# 23                                                               Can anyone suggest me a good phone under Rs. 30k ($450) which is also available in India?
# 24                                                                                                                    How can I make 1000$ monthly online?
#
#                                                                                                                                                                                                                                                                                                  question2
# 0                                                                                                                                                                                                            What will be the impact of scrapping of ₹500 and ₹1000 rupee notes on the real estate market?
# 1                                                                                                                                                                                                                                                      How can I best invest ₹5000 over the next 6 months?
# 2                                                                                                                                                                                                                                    What are your views on demonetization of ₹500 & ₹1000 notes in India?
# 3                                                                                                                                                                                                                                               Can I live comfortably in DC on $80,000 - $114,000 salary?
# 4                                                                                                                                                                   I own a multinational company worth $450 million dollars, and I want to prepare my son to be the future CEO. What should I advise him?
# 5                                                                                                                                                                                 What are going to be the rammifications of the Indian government's decision affecting invalid ₹500/₹1000 currency notes?
# 6                                                                                                                                                                                                                                                       What is the best thing I can buy for 2€ on Amazon?
# 7                                                                                                                                                                                                                           How do I ship 100 kgs of luggage (clothes) from the USA to India, within $150?
# 8                                                                                                                                                                                                                                       Can a family live comfortable on $150,000 a year in New York City?
# 9                                                                                                                                                                                                                                                                              What does "$" mean in Java?
# 10                                                                                                                                                                                                                                   Should the minimum wage be raised to $15/hr for all American workers?
# 11                                                                                                                                                                                                       The real effective way to make $ 500 per month with the knowledge that I have no money to invest?
# 12                                                                                                                                                                                                                                            If 138 trash bags cost $16.50 then what's the cost of 1 bag?
# 13                                                                                                                                                                                                                                                     What side business can make you $1000-$2000 a week?
# 14                                                                                                                                                                                                                                     How will discontinuing ₹500 and ₹1000 notes affect India's economy?
# 15                                                                                                                                                                                                              RBI is planning to destroy 1000₹&500₹ notes, can't they recycle them for 100₹ & 50₹ notes?
# 16                                                                                                                                                                                                                          Will the economy of India collapse due to the banning of ₹500 and ₹1000 notes?
# 17                                                                                                                                                                                                                                                     Can a family of 4 live comfortably by $1800/salary?
# 18                                                                                                                                                                                                                                                                          Can you be rich with $500,000?
# 19    I am an Indian citizen currently living in the US. Can I move back to India and still hold a source of income in the US such that I earn money in US $? What ways can you think of which is a win win situation where we can head back to our home land and still earn money in the US salary range?
# 20  I recently took out a $4.5K loan for school, but I just found out that with my two jobs, I should be able to cover it on my own. I am still getting the money however. I am an aspiring musician, and I am not sure what to do with the money. What would be a good investment, or should I return it?
# 21                                                                                                                                                                                                                                                                      How do I make $1000 extra dollars?
# 22                                                                                                                                                                                                         I just broke a bone in my foot. Is it worth spending $500 to get an ultrasound bone stimulator?
# 23                                                                                                                                                                                                                                                       What is the best car to buy for around $200K USD?
# 24                                                                                                                                                                                                                                                      What is the most attractive car for under $10,000?

# %%
# Solution: replace with acronyms

def convert_currency_symbols(text):
    currency_map = {
        '$': 'USD',
        '€': 'EUR',
        '£': 'GBP',
        '¥': 'JPY',
        '₹': 'INR'
    }
    # Replace each currency symbol with its acronym
    for symbol, code in currency_map.items():
        text = text.replace(symbol, f' {code} ')
    return re.sub(r'\s+', ' ', text).strip()  # Clean up spacing

df['q1_currency'] = df['question1'].apply(convert_currency_symbols)
df['q2_currency'] = df['question2'].apply(convert_currency_symbols)

# Check results
q1_currency = df[df['q1_currency'].astype(str).str.contains(currency_symbols, regex=True)]
q2_currency = df[df['q2_currency'].astype(str).str.contains(currency_symbols, regex=True)]
print(f"Total questions with currency symbols in question1: {len(q1_currency)}")
print(f"Total questions with currency symbols in question2: {len(q2_currency)}")
currency_examples = pd.concat([q1_currency['q1_currency'].reset_index(drop=True), q2_currency['q2_currency'].reset_index(drop=True)], axis=1)
currency_examples[['q1_currency', 'q2_currency']].head(25)
# Out:
# Total questions with currency symbols in question1: 0
# Total questions with currency symbols in question2: 0
# Empty DataFrame
# Columns: [q1_currency, q2_currency]
# Index: []

# %% [markdown]
# ## Step 5: Comprehensive Cleaning Functions
# After addressing individual issues, we define comprehensive cleaning functions that combine all previous steps. Multiple cleaning strategies are created (squeaky, light, transformer) to suit different modeling needs, from aggressive cleaning to minimal.

# %%
# The usual NLP preprocessing steps

stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()

def strip_whitespace(text):
  return re.sub(r'\s+', ' ', text).strip()

def remove_punctuation(text):
  return re.sub(r'[^\w\s]', ' ', text)

def remove_stopwords(text):
  tokens = text.split()
  tokens = [word for word in tokens if word not in stop_words]
  return ' '.join(tokens)

def stem_words(text):
  tokens = text.split()
  tokens = [stemmer.stem(word) for word in tokens]  
  return ' '.join(tokens)

# %%
# Final total and complete cleaning

def squeaky_cleaning(text):
  text = tag_to_token(text)
  text = normalize_unicode(text)
  text = expand_contractions(text)
  text = remove_possesives(text)
  text = convert_currency_symbols(text)
  text = text.lower()
  text = remove_punctuation(text)
  text = remove_stopwords(text)
  text = stem_words(text)
  text = strip_whitespace(text)
  return text

def light_cleaning(text):
  text = tag_to_token(text)
  text = normalize_unicode(text)
  text = expand_contractions(text)
  text = remove_possesives(text)
  text = convert_currency_symbols(text)
  text = text.lower()
  text = remove_punctuation(text)
  text = remove_stopwords(text)
  text = strip_whitespace(text)
  return text

def transformer_cleaning(text):
  text = tag_to_token(text)
  text = normalize_unicode(text)
  text = expand_contractions(text)
  text = convert_currency_symbols(text)
  text = strip_whitespace(text)
  return text

df['question1_squeaky'] = df['question1'].astype(str).progress_apply(squeaky_cleaning)
df['question2_squeaky'] = df['question2'].astype(str).progress_apply(squeaky_cleaning)

df['question1_light'] = df['question1'].astype(str).progress_apply(light_cleaning)
df['question2_light'] = df['question2'].astype(str).progress_apply(light_cleaning)

df['question1_transformer'] = df['question1'].astype(str).progress_apply(transformer_cleaning)
df['question2_transformer'] = df['question2'].astype(str).progress_apply(transformer_cleaning)

# %% [markdown]
# Save the cleaned csv to use in the main notebook.

# %%
df = df[['question1', 'question2', 'question1_squeaky', 'question2_squeaky', 'question1_light', 'question2_light', 'question1_transformer', 'question2_transformer', 'is_duplicate']]

df.to_csv('quora_cleaned.csv', index=False)

# %% [markdown]
# ## Step 6: Inspecting Missing and Invalid Data
# After cleaning, it is interesting to check for rows with missing, empty, or invalid questions.

# %%
def missingness(df, col):
  # Look for 'fake' NaNs: string entries that literally say "nan"
  mask_q1_string_nan = df[col].astype(str).str.lower().eq('nan')

  print(f"'nan' strings in {col}: {mask_q1_string_nan.sum()}")

  # Look for fully empty strings or just whitespace
  mask_q1_empty = df[col].astype(str).str.strip() == ''

  print(f"Empty strings in {col}: {mask_q1_empty.sum()}")

for col in ['question1', 'question2', 'question1_squeaky', 'question2_squeaky', 'question1_light', 'question2_light', 'question1_transformer', 'question2_transformer']:
  missingness(df, col)
# Out:
# 'nan' strings in question1: 1
# Empty strings in question1: 0
# 'nan' strings in question2: 2
# Empty strings in question2: 0
# 'nan' strings in question1_squeaky: 1
# Empty strings in question1_squeaky: 85
# 'nan' strings in question2_squeaky: 2
# Empty strings in question2_squeaky: 72
# 'nan' strings in question1_light: 1
# Empty strings in question1_light: 85
# 'nan' strings in question2_light: 2
# Empty strings in question2_light: 72
# 'nan' strings in question1_transformer: 1
# Empty strings in question1_transformer: 0
# 'nan' strings in question2_transformer: 2
# Empty strings in question2_transformer: 0

# %%
mask_q1_valid = ~df['question1'].str.lower().eq('nan')
mask_q2_valid = ~df['question2'].str.lower().eq('nan')

# Keep only rows where both questions are valid
df = df[mask_q1_valid & mask_q2_valid]

# %%
empty_q1 = df['question1_squeaky'].astype(str).str.strip() == ''
empty_q2 = df['question2_squeaky'].astype(str).str.strip() == ''

# Combine the two masks
empty_rows = df[empty_q1 | empty_q2]

# Display them
print(f"Total rows with empty cleaned questions: {len(empty_rows)}")
empty_rows[['question1','question1_squeaky', 'question2','question2_squeaky']].head(25)
# Out:
# Total rows with empty cleaned questions: 136
#                                                                                                                    question1  \
# 3306                                                                                                                       .
# 7120                                                                     Is it proper to use a comma after saying thank you?
# 9581                                                                                               How can I just be myself?
# 13016                                                                                                                      ?
# 17486                   I am neither good at studies nor at anything else, what should a loser like me do to transform self?
# 19007                                                                                                       What is hirarki?
# 20072                                                                                                How could I solve this?
# 20794                                                                                                                      ?
# 25228                                                                                                                  What?
# 26795                                                                                                         What is quoro?
# 29040                                                                                     What is what and why is that what?
# 35641                                                                                                           What to do ?
# 39405                                                                                                            Where can I
# 42312                                                                                                        What is S.O.P.?
# 42947                                                                                            How could I do this to her?
# 45883                                                                                     What is what and why is that what?
# 46596                                                                                                       How To Edit DNA?
# 47056  Is there anywhere in the world offering pain management for peripheral neuropathy as opioids haved been banned in US?
# 51909                                                     What should yellow taxis do to face competition from Ola and Uber?
# 54029                                                                                                                   I'm
# 55507                                                                                                          What is clax?
# 58566                                                                                                      What is goodwell?
# 63712                                                                                                                  What?
# 65766                                                                    What should I do next after opening Gentoo website?
# 67219                                                                                 How do I prepare last-minute for JEE ?
#
#                                                            question1_squeaky  \
# 3306
# 7120                                              proper use comma say thank
# 9581
# 13016
# 17486                 neither good studi anyth els loser like transform self
# 19007                                                                hirarki
# 20072                                                             could solv
# 20794
# 25228
# 26795                                                                  quoro
# 29040
# 35641
# 39405
# 42312                                                                      p
# 42947                                                                  could
# 45883
# 46596                                                               edit dna
# 47056  anywher world offer pain manag peripher neuropathi opioid have ban us
# 51909                                     yellow taxi face competit ola uber
# 54029
# 55507                                                                   clax
# 58566                                                                goodwel
# 63712
# 65766                                                next open gentoo websit
# 67219                                                  prepar last minut jee
#
#                                                                                   question2  \
# 3306                               Why is Cornell's endowment the lowest in the Ivy League?
# 7120                                                            What is here and not there?
# 9581                                                               How can I not be myself?
# 13016                                                    Why should one not work at Google?
# 17486                                                    If + * + = + then why - * - ! = -?
# 19007                                                                    What is "what is"?
# 20072                                                                                …………..
# 20794                                     What is the Gmail tech support help phone number?
# 25228                             What should Indians do if Donald Trump becomes President?
# 26795                                                                            What is ∀?
# 29040                                                                   What is up and why?
# 35641                                                                           What to do?
# 39405                                      Where can I get 'Simba, The King Lion' in Hindi?
# 42312                                                                          What is s/o?
# 42947                                                                     How do I do this?
# 45883                                                What is it that you are doing and why?
# 46596                                                                                 What?
# 47056                                                                                     ?
# 51909                                                                                 What?
# 54029                          I am a 39 year old single woman. Should I have a baby alone?
# 55507                                                                            What is #?
# 58566                                                                    What is "what is"?
# 63712  What is the average processing time for a spouse sponsorship in Canada after appeal?
# 65766                                                               What do I do with this?
# 67219                                                                     What should I do?
#
#                                          question2_squeaky
# 3306                         cornel endow lowest ivi leagu
# 7120
# 9581
# 13016                                       one work googl
# 17486
# 19007
# 20072
# 20794                 gmail tech support help phone number
# 25228                     indian donald trump becom presid
# 26795
# 29040
# 35641
# 39405                            get simba king lion hindi
# 42312
# 42947
# 45883
# 46596
# 47056
# 51909
# 54029                    39 year old singl woman babi alon
# 55507
# 58566
# 63712  averag process time spous sponsorship canada appeal
# 65766
# 67219

# %% [markdown]
# Another thing to keep in mind is questions that are too short even before cleaning, indicating possible bad quality of the raw dataset.

# %%
# Helper: Count words after stripping whitespace
def is_too_short(text):
    if not isinstance(text, str):
        return True
    return len(text.strip().split()) <= 1

# Apply to both columns
short_q1 = df['question1'].apply(is_too_short)
short_q2 = df['question2'].apply(is_too_short)

# Combine masks
short_rows = df[short_q1 | short_q2]

# Display them
print(f"Total rows with very short questions: {len(short_rows)}")
short_rows[['question1', 'question2', 'is_duplicate']]
# Out:
# Total rows with very short questions: 91
#                                                                                                                                                                             question1  \
# 3306                                                                                                                                                                                .
# 13016                                                                                                                                                                               ?
# 17682                                                                                                                                                                         deleted
# 20072                                                                                                                                                         How could I solve this?
# 20794                                                                                                                                                                               ?
# 23305                                                                                                                                                                         deleted
# 23884                                                                                                                                                                              HH
# 25228                                                                                                                                                                           What?
# 25315                                                                                                                                                                         deleted
# 39769                                                                                                                                                                         deleted
# 44619                                                                                                                                                                              Na
# 46596                                                                                                                                                                How To Edit DNA?
# 47056                                                           Is there anywhere in the world offering pain management for peripheral neuropathy as opioids haved been banned in US?
# 51909                                                                                                              What should yellow taxis do to face competition from Ola and Uber?
# 54029                                                                                                                                                                            I'm
# 57484                                                                                                                                                                         grammar
# 63712                                                                                                                                                                           What?
# 74304                                                                                                                                   Is there any chances for hailstones tomorrow?
# 86457                                                                                                                                                                             Is?
# 87861                                                                                                                                                                        Deleted.
# 96725                                                                                                                                                                               ?
# 104101                                                                                                                                                                              ?
# 106577                                                                                                                                                                          What?
# 108978                                                                                                                                                                              i
# 109009                                                              How do I make a box that I can put my phone in it when I don't want the microphone to listen to my conversations?
# 109311                                                                                                                                                                           What
# 115347                                                                                                                                                                              o
# 130637                                                                                          Does the Quran surah 23: 5-6 prove that Allah allows the female captives to be raped?
# 134403                                                                                                                                                                              ?
# 139219                                                                                                                                                                        deleted
# 141281                                                                                                                                                                       Deleted.
# 144506                                                                                                                                            How beautiful do you think you are?
# 145000                                         Me and my girlfriend wish to go out and do 'stuff' and we have just public places to go to, where can we do it without anyone knowing?
# 151922                                                                                                                                                                              o
# 158778                                                                                                                                                                              A
# 164553                                                                                                                                                                           Nana
# 169290                                                                                                                                                                            111
# 175282                                                                                                                                                                            Hh
# 175584                                                                                                                                                                           I'm
# 180461                                                                                                                                                                           spam
# 181695                                                                                                                          Why does the page reload every time I try to comment?
# 182943                                                                                                                                                                      [removed]
# 189396                                                                                                                                                                          Which
# 189659                                                                                                                                                                              ?
# 190570                                                                                                                                                                              ‘
# 193246  What was it like to be in the game industry during the moral panic against video games caused by mainstream media coverage of games like Night Trap, Doom, and Mortal Kombat?
# 193815                                                                                                                                                                        deleted
# 198913                                                                                                                                                                  What is this?
# 199110                                                                                                                                                                              I
# 205947                                                                                                                                                                       Deleted.
# 208199                                Happiness! We offer a seat or help others because the act makes us feel good .Everything  is done for our own happiness .Why are we so selfish?
# 208485                                                                                                                                                                              ?
# 208798                                                                                                                                                                           Can?
# 213220                                                                                                                                                                              ?
# 216861                                                                                                                                                                           Aaas
# 226925                                                                                               Which in the best bike desert storm or Himalayan. I m gona buy in next 3 months?
# 231151                                                                                                                                                                       Marriage
# 231313                                                                                                                         From where to download episode2 season 3 of The Flash?
# 231879                                                                                                                                                                        deleted
# 236655                                                                                                                                                   Why was spam is called spam?
# 245880                                                                                                                                                                            sss
# 248125                                                                                                                                                                        deleted
# 254161                                                                                                                                                                              ?
# 257077                                                                                                                                                                             hi
# 260779                                                                                                                                                                           Why?
# 263134                                                                                                                                                                         delete
# 270146                                                                                                                                                                             Ok
# 273065                                                                                                                                                                              ?
# 289307                                                              How do I make a box that I can put my phone in it when I don't want the microphone to listen to my conversations?
# 297461                                                                                                                                                                          civil
# 301583                                                                                                                                                                            …..
# 306878                                                                                                        Is the electric field in the cavity of a hollow charged conductor zero?
# 312498                                                                                                                                                                          What?
# 322261                                                                                                                                                     Am I cursed with bad luck?
# 322705                                                                                                                                                                       Cloning?
# 324777                                                                                                                                                                           Why?
# 325200                                                                                                                                                                          Error
# 325530                                                                                                                                                                             My
# 326297                                                                                                                                                                            How
# 327206                                                                                                                                                                          Life:
# 328601                                                                                                                                                                             My
# 328745                                                                                                                                                                          lol ?
# 348571                                                                                                                                                                       Deleted.
# 351788                                                                                                                                                                             Q?
# 356434                                                                                                                                                                       Deleted.
# 357127                                                                                                                                                                              H
# 361480                                                                                                                      As a 13 year old, how do I get out of my unlivable house?
# 365317                                                                                                                                                                        deleted
# 381124                                                                                                                                                                             no
# 384293                                                                                                                                                           How do I solve this?
# 402423                                                                                                                                                                              ?
#
#                                                                                                                                                                                   question2  \
# 3306                                                                                                                               Why is Cornell's endowment the lowest in the Ivy League?
# 13016                                                                                                                                                    Why should one not work at Google?
# 17682                                                                                                                   Which website will be suitable for downloading eBooks and lectures?
# 20072                                                                                                                                                                                …………..
# 20794                                                                                                                                     What is the Gmail tech support help phone number?
# 23305                                                                                                            Which are some best websites for downloading newly published books/eBooks?
# 23884                                                                                                                                                                           What is hh?
# 25228                                                                                                                             What should Indians do if Donald Trump becomes President?
# 25315                                                                                               What kind of questions on Quora aren't OK? What is Quora's policy on question deletion?
# 39769                                                                                                                                What is a website where I can download eBooks legally?
# 44619                                                                                                                                                    How do I activate Reliance Jio 4G?
# 46596                                                                                                                                                                                 What?
# 47056                                                                                                                                                                                     ?
# 51909                                                                                                                                                                                 What?
# 54029                                                                                                                          I am a 39 year old single woman. Should I have a baby alone?
# 57484                                                                                                                                                                      What is grammar?
# 63712                                                                                                  What is the average processing time for a spouse sponsorship in Canada after appeal?
# 74304                                                                                                                                                                         parisflatlist
# 86457                                                                                                                                               Does mother/son incest happen in India?
# 87861                                                                                                                  How do I send notification from server to Android without using GCM?
# 96725                                                                                                                                                       Who are Moses, Noah and Exodus?
# 104101                                Problem of solving a problem is not a problem, but when a problem solves a problem without any problem then the problem is not at all a problem, why?
# 106577                                                                                                                                What should a young person do after his office works?
# 108978                                                                                                                                                  What questions to ask any drdummer?
# 109009                                                                                                                                                                                   Hh
# 109311                                                                    What are the options for getting fee concessions in BITS for economically weaker sections with income below 2lpa?
# 115347                                                                                                                                      Where can I watch free streaming movies online?
# 130637                                                                                                                                                                                Does?
# 134403                                     What is your take on the undercover report that hints that Indian gov plans to capture kshatriya caste people and sends them to Indo-Pak border?
# 139219                                                                                                                                Where can I get online PDF or EPUB versions of books?
# 141281                                                                                                                                                                                null
# 144506                                                                                                                                                                               Delete
# 145000                                                                                                                                                                             Deleted.
# 151922                                                 What is this - “This website/URL has been blocked as per instructions from Department of Telecommunications and/or Courts of India.”
# 158778                                                                                                                                  Do men forgive their wives when they cheat on them?
# 164553  If my ex-girfriend of 2 years tries to come back to me after just 1 week since we broke up, stating that she understood our issues and that she can solve them, should I trust her?
# 169290                                                                  I'm looking for the book Intelligent Investor by Benjamin Graham.  Do you think I can find it at my local library?
# 175282                                                                                                                                                                                   HH
# 175584                                                                                                                   I am 25 yrs old and I am still virgin. How can I change this fact?
# 180461                                                                                                                                                         Why was spam is called spam?
# 181695                                                                                                                                                                                  Why
# 182943                                                                                                                                                     Is playing video games immature?
# 189396                                                                                                 Which Fake GPS with Joystick app will work for Pokémon go in Redmi note 3(Lollipop)?
# 189659                                                                                                                                                                         Who is Noah?
# 190570                                                                                                                                    Time is money.Can some one explain, how it works?
# 193246                                                                                                                                                                            [removed]
# 193815                                                                                                                                             What is the best site to download books?
# 198913                                                                                                                                                                                    o
# 199110                                                                                                                What is the connection between Donald trump and Norman Vincent peale?
# 205947                                                                                                                                                                                Null
# 208199                                                                                                                                                                                 Edit
# 208485                                                                                Given that PACER makes money from usage, why does the legal profession tolerate its absurd awfulness?
# 208798                                                                                            Can I insure a vehicle and receive a license plate without possessing a driver's license?
# 213220                                                                                                                                                   What is it like to work at Google?
# 216861                                                                                                                  My dad always yells at me and causes me anxiety. How do I fix this?
# 226925                                                                                                                                                                                 ????
# 231151                                                                                                                                   "Marriage is an institution." What does this mean?
# 231313                                                                                                                                                                              deleted
# 231879                                                                                                                                  What are the best websites to download ebooks from?
# 236655                                                                                                                                                                                 Spam
# 245880                                                                                                                                                                         What is sss?
# 248125                                                                                                                                          How can I download flash season 2 episodes?
# 254161                                         How do I convince my non-Indian friends that not all Indians are cow worshippers and not all of them text every woman they find on Facebook?
# 257077                                                                                               What should I do to get my ex-girlfriend back if she does not even want to talk to me?
# 260779                                                                                                                                                           Why can't mules reproduce?
# 263134                                                                                              What kind of questions on Quora aren't OK? What is Quora's policy on question deletion?
# 270146                                                                                                                                               What would you do if you were wealthy?
# 273065                                                                                                                              How can I describe Quora, in all its glory, to friends?
# 289307                                                                                                                                                                                  Hh
# 297461                                                                                                                                                   What is best DSLR? Canon or Nikon?
# 301583                                                                                                                                                          What do I do with this guy?
# 306878                                                                                                                                                                                What?
# 312498                                                                                                            What is life like at MAMC? How are the hostel facilities and the seniors?
# 322261                                                                                                                                                                             Deleted.
# 322705                                                                                                                                                            To clone or not to clone?
# 324777                                                                                                                                      Why are answers and reviews on Quora collapsed?
# 325200                                                                                                                                       Will there be an error in measuring the error?
# 325530         My boyfriend told me he was not as attracted to me like he has been with past girlfriends. I don't know even what to say to this, or how to feel but hurt. What should I do?
# 326297                                                                                                                                 What are some of the best ways to learn programming?
# 327206                                                                                                                                                                What is life of life?
# 328601                                                           My father has many new technologies with him (many fields) who can he approach to get it implemented (to get it financed)?
# 328745                                                                                                                                                                                  lol
# 348571                                                                                                                       Should I be happy for her? Or does this make her a bad friend?
# 351788                                 I have some secrets..what if I smoke marijuana with my boyfriend and he asks me about the past, will I control my answers and not telling the truth?
# 356434                                                                                                       Do gay men find red headed men more attractive than women find red headed men?
# 357127                                                                                                                                                        Should I forgive the cheater?
# 361480                                                                                                                                                                                 Spam
# 365317                                                                                                                                           From which site I can download GTA 4 game?
# 381124                                                           I have a BS and MPH and hate my job. I found that I love working with website design but is it worth going back to school?
# 384293                                                                                                                                                                               …………..
# 402423                                                                                                                                 What is cisco router technical support phone number?
#
#         is_duplicate
# 3306               0
# 13016              0
# 17682              0
# 20072              0
# 20794              0
# 23305              0
# 23884              0
# 25228              0
# 25315              0
# 39769              0
# 44619              0
# 46596              0
# 47056              0
# 51909              0
# 54029              0
# 57484              0
# 63712              0
# 74304              0
# 86457              0
# 87861              0
# 96725              0
# 104101             0
# 106577             0
# 108978             0
# 109009             0
# 109311             0
# 115347             0
# 130637             0
# 134403             0
# 139219             0
# 141281             0
# 144506             0
# 145000             0
# 151922             0
# 158778             0
# 164553             0
# 169290             0
# 175282             1
# 175584             0
# 180461             0
# 181695             0
# 182943             0
# 189396             0
# 189659             0
# 190570             0
# 193246             0
# 193815             0
# 198913             0
# 199110             0
# 205947             0
# 208199             0
# 208485             0
# 208798             0
# 213220             0
# 216861             0
# 226925             0
# 231151             0
# 231313             0
# 231879             0
# 236655             0
# 245880             0
# 248125             0
# 254161             0
# 257077             0
# 260779             0
# 263134             0
# 270146             0
# 273065             0
# 289307             0
# 297461             0
# 301583             0
# 306878             0
# 312498             0
# 322261             0
# 322705             0
# 324777             0
# 325200             0
# 325530             0
# 326297             0
# 327206             0
# 328601             0
# 328745             1
# 348571             0
# 351788             0
# 356434             0
# 357127             0
# 361480             0
# 365317             0
# 381124             0
# 384293             0
# 402423             0

# %% [markdown]
# Please note that those cases identified above were intnentionally kept and not discarded, because we decided that it's worth exploring how our models will handle them.

# %% [markdown]
# # Next Steps
# The cleaned data is now ready for feature engineering and model development for duplicate question detection.
